# %%
# !pip install -q tensorflow-gpu==2.7.0rc1
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0-rc1

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix

# %%
cifar10 = tf.keras.datasets.cifar10

(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

X_train, X_test = X_train/255., X_test/255. 

print(f"Shape of X train is: {X_train.shape}")
# Out:
# Shape of X train is: (50000, 32, 32, 3)

# %%
Y_train, Y_test = Y_train.flatten(), Y_test.flatten()

print(f"Shape of Y train is: {Y_train.shape}")
# Out:
# Shape of Y train is: (50000,)

# %%
k = len(set(Y_train))
print(f"Number of labels in dataset is {k}")
# Out:
# Number of labels in dataset is 10

# %%
i = Input(shape=X_train[0].shape)
x = Conv2D(32, (3,3), strides=2 ,activation='relu')(i)
x = Conv2D(64, (3,3), strides=2 ,activation='relu')(x)
x = Conv2D(128, (3,3), strides=2 ,activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(k, activation='softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=15)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.5858 - accuracy: 0.4233 - val_loss: 1.2998 - val_accuracy: 0.5254
# Epoch 2/15
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.2959 - accuracy: 0.5370 - val_loss: 1.1581 - val_accuracy: 0.5887
# Epoch 3/15
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.1627 - accuracy: 0.5825 - val_loss: 1.0652 - val_accuracy: 0.6174
# Epoch 4/15
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.0809 - accuracy: 0.6129 - val_loss: 0.9952 - val_accuracy: 0.6459
# Epoch 5/15
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.0065 - accuracy: 0.6417 - val_loss: 0.9555 - val_accuracy: 0.6615
# Epoch 6/15
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.9486 - accuracy: 0.6615 - val_loss: 0.9159 - val_accuracy: 0.6759
# Epoch 7/15
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.9057 - accuracy: 0.6762 - val_loss: 0.9247 - val_accuracy: 0.6779
# Epoch 8/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.8641 - accuracy: 0.6938 - val_loss: 0.9061 - val_accuracy: 0.6848
# Epoch 9/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.8171 - accuracy: 0.7099 - val_loss: 0.8544 - val_accuracy: 0.7027
# Epoch 10/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.7916 - accuracy: 0.7194 - val_loss: 0.8464 - val_accuracy: 0.7044
# Epoch 11/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.7545 - accuracy: 0.7320 - val_loss: 0.8641 - val_accuracy: 0.7025
# Epoch 12/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.7325 - accuracy: 0.7373 - val_loss: 0.8479 - val_accuracy: 0.7065
# Epoch 13/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.7006 - accuracy: 0.7514 - val_loss: 0.8386 - val_accuracy: 0.7104
# Epoch 14/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.6880 - accuracy: 0.7541 - val_loss: 0.8433 - val_accuracy: 0.7060
# Epoch 15/15
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.6623 - accuracy: 0.7645 - val_loss: 0.8400 - val_accuracy: 0.7107

# %%
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='Validation_Loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='Validation_accuracy')
plt.legend()

# %%
model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8400 - accuracy: 0.7107
# [0.8399696350097656, 0.7106999754905701]

# %%
import itertools

def plot_confusion_matrix(cm, classes, normalize=False, 
                          title="Confusion Matrix",
                          cmap=plt.cm.Accent,):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized Confusion Matrix")
    else:
        print("Confusion Matrix, Without Normalization")

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45) 
    plt.yticks(tick_marks, classes) 

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2. 
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment='center',
        color="white" if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.xlabel('True Labels')
    plt.ylabel('Predicted Labels')
    plt.show()

p_test = model.predict(X_test).argmax(axis=1)
cm = confusion_matrix(Y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion Matrix, Without Normalization
# [[729  19  52  20  23   9  11   7 100  30]
#  [ 14 853   9   8   3   1  18   2  30  62]
#  [ 67   5 611  84  93  35  63  20  14   8]
#  [ 13  12  75 574  71 128  87  19  11  10]
#  [ 14   4  72  69 678  29  73  38  18   5]
#  [ 13   4  73 254  50 525  46  21   7   7]
#  [  6   4  41  52  30  18 840   3   3   3]
#  [ 15   2  38  68  87  55  14 699   8  14]
#  [ 50  30  13  16  10   3   5   4 847  22]
#  [ 39 102   6  24   6   8  11  14  39 751]]

# %%
misclassified_idx = np.where(p_test!=Y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(X_test[i], cmap='gray')
plt.title("True Label: %s Predicted: %s" % (Y_test[i], p_test[i]))
# Out:
# Text(0.5, 1.0, 'True Label: 6 Predicted: 4')
